# %%
import pandas as pd

gdf = pd.read_pickle("krakow-buildings.pkl")

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ## Columns

# %%
columns = sorted(gdf.columns)

# Print column names and their data types
for col in columns:
    print(f"{col}: {gdf[col].dtype}")
# Out:
# 3dr:height1: object
# 3dr:height2: object
# 3dr:length1: object
# abandoned: object
# abandoned:building: object
# abandoned:power: object
# access: object
# addr:city: object
# addr:city:simc: object
# addr:country: object
# addr:district: object
# addr:door: object
# addr:housename: object
# addr:housenumber: object
# addr:old_street: object
# addr:place: object
# addr:postcode: object
# addr:province: object
# addr:state: object
# addr:street: object
# addr:street:sym_ul: object
# addr:subdistrict: object
# addr:suburb: object
# addr:unit: object
# admin_level: object
# aeroway: object
# air_conditioning: object
# alt_addr:street: object
# alt_name: object
# alt_name:en: object
# amenity: object
# amenity_1: object
# animal_boarding: object
# architect: object
# architect:wikidata: object
# area: object
# artwork_type: object
# atm: object
# audio: object
# automated: object
# bar: object
# barrier: object
# beauty: object
# beds: object
# bell: object
# bell:name: object
# bells: object
# bench: object
# bicycle_parking: object
# biergarten: object
# bin: object
# branch: object
# brand: object
# brand:wikidata: object
# brand:wikipedia: object
# brewery: object
# bridge:support: object
# building: object
# building:architecture: object
# building:colour: object
# building:condition: object
# building:flats: object
# building:level:-1: object
# building:levels: object
# building:levels:aboveground: object
# building:levels:roof: object
# building:levels:underground: object
# building:material: object
# building:max_level: object
# building:min_level: object
# building:part: object
# building:parts: object
# building:prefabricated: object
# building:roof: object
# building:start_date: object
# building:use: object
# building:use:parking: object
# building:use:residential: object
# building:use:retail: object
# building_1: object
# bunker_type: object
# bus: object
# by:religious_title: object
# by:shrine: object
# capacity: object
# capacity:disabled: object
# carpenter: object
# cash_withdrawal:operator: object
# castle_type: object
# changing_table: object
# charge: object
# check_date: object
# check_date:compressed_air: object
# check_date:opening_hours: object
# church:id: object
# church:type: object
# closed: object
# clothes: object
# club: object
# collection_times: object
# college: object
# colour: object
# communication:mobile_phone: object
# company: object
# compressed_air: object
# compressed_air:fee: object
# consecrated: object
# construction: object
# construction_date: object
# consulate: object
# contact:email: object
# contact:facebook: object
# contact:fax: object
# contact:instagram: object
# contact:mobile: object
# contact:phone: object
# contact:website: object
# content: object
# country: object
# covered: object
# craft: object
# crop: object
# cuisine: object
# date:consecrated: object
# date:religious_title: object
# date:shrine: object
# deanery: object
# dedicated_to:wikidata: object
# defensive_works: object
# delivery: object
# demolished:building: object
# denomination: object
# departures_board: object
# depot: object
# description: object
# description:en: object
# description:hu: object
# designation: object
# devices: object
# diet:dairy_free: object
# diet:egg_free: object
# diet:halal: object
# diet:keto: object
# diet:kosher: object
# diet:lactose_free: object
# diet:meat: object
# diet:non-vegetarian: object
# diet:plant-based: object
# diet:poultry: object
# diet:vegan: object
# diet:vegetarian: object
# diocese: object
# diplomatic: object
# dispensing: object
# disused: object
# disused:amenity: object
# disused:building: object
# disused:man_made: object
# disused:recycling_type: object
# disused:shop: object
# disused:tourism: object
# drinking_water: object
# drive_in: object
# drive_through: object
# ele: object
# email: object
# emergency: object
# emergency:phone: object
# end_date: object
# facebook: object
# faculty: object
# fast_food: object
# fax: object
# fee: object
# fee:conditional: object
# female: object
# female:conditional: object
# female:signed: object
# fixme: object
# fixme:requires_aerial_image: object
# flickr: object
# former:amenity: object
# free_day: object
# frequency: object
# fuel:GTL_diesel: object
# fuel:HGV_diesel: object
# fuel:adblue: object
# fuel:biodiesel: object
# fuel:diesel: object
# fuel:diesel_B: object
# fuel:lpg: object
# fuel:octane_95: object
# fuel:octane_98: object
# full_name: object
# furniture: object
# gas_insulated: object
# generator:method: object
# generator:output:electricity: object
# generator:output:hot_water: object
# generator:source: object
# generator:type: object
# geom: geometry
# government: object
# guest_house: object
# healthcare: object
# healthcare:speciality: object
# heating: object
# height: object
# heritage: object
# heritage:operator: object
# heritage:website: object
# highway: object
# historic: object
# historic:building: object
# historic:civilization: object
# house: object
# id: int64
# image: object
# indoor: object
# indoor_seating: object
# industrial: object
# information: object
# inscription: object
# int_name: object
# internet_access: object
# internet_access:captive_portal: object
# internet_access:fee: object
# internet_access:password: object
# internet_access:ssid: object
# isced:level: object
# landuse: object
# language:en: object
# layer: object
# leisure: object
# level: object
# lgbtq: object
# lit: object
# loc_name: object
# location: object
# lockable: object
# locked: object
# lottery: object
# male: object
# male:signed: object
# man_made: object
# manufacturer: object
# manufacturer:type: object
# manufacturer:wikidata: object
# material: object
# max_level: object
# military: object
# millennium:date: object
# millennium:network: object
# millennium:ref: object
# millennium:subtype: object
# min_height: object
# min_level: object
# mobile: object
# monastery:type: object
# museum: object
# name: object
# name:af: object
# name:ar: object
# name:be: object
# name:bg: object
# name:ca: object
# name:cs: object
# name:de: object
# name:el: object
# name:en: object
# name:es: object
# name:et: object
# name:etymology:wikidata: object
# name:fi: object
# name:fr: object
# name:he: object
# name:hr: object
# name:hu: object
# name:id: object
# name:it: object
# name:ja: object
# name:ko: object
# name:lt: object
# name:mk: object
# name:nl: object
# name:pl: object
# name:pt: object
# name:ro: object
# name:ru: object
# name:signed: object
# name:sk: object
# name:sv: object
# name:th: object
# name:uk: object
# name:zh: object
# natural: object
# network: object
# network:wikidata: object
# nid:inscription_date: object
# noaddress: object
# noexit: object
# nohousenumber: object
# noname: object
# note: object
# note:fee: object
# number_of_apartments: object
# nursery: object
# office: object
# official_name: object
# official_name:en: object
# old_alt_name: object
# old_name: object
# old_name:de: object
# old_name:hu: object
# old_ref: object
# opening_date: object
# opening_hours: object
# opening_hours:atm: object
# opening_hours:signed: object
# opening_hours:source: object
# operator: object
# operator:type: object
# operator:wikidata: object
# operator:wikipedia: object
# outdoor_seating: object
# owner: object
# parish: object
# parish:wikidata: object
# parish:wikipedia: object
# park_ride: object
# parking: object
# parking:levels: object
# patron: object
# payment:american_express: object
# payment:amic_fleet_card: object
# payment:bancomat: object
# payment:blik: object
# payment:cards: object
# payment:cash: object
# payment:coins: object
# payment:contactless: object
# payment:credit_cards: object
# payment:cryptocurrencies: object
# payment:debit_cards: object
# payment:diners_club: object
# payment:dkv: object
# payment:e100: object
# payment:electronic_purses: object
# payment:eurowag: object
# payment:funn: object
# payment:google_pay: object
# payment:logpay: object
# payment:maestro: object
# payment:mastercard: object
# payment:nfc: object
# payment:notes: object
# payment:others: object
# payment:routex: object
# payment:sodexo: object
# payment:uta: object
# payment:v_pay: object
# payment:viada: object
# payment:visa: object
# payment:visa_debit: object
# payment:visa_electron: object
# payment:vitay: object
# phone: object
# phone:mobile: object
# phone:service: object
# phone:shop: object
# phone_1: object
# phone_2: object
# power: object
# preschool: object
# product: object
# proposed: object
# public_transport: object
# railway: object
# railway:local_operated: object
# railway:ref: object
# railway:signal_box: object
# rating: object
# recycling:cardboard: object
# recycling:clothes: object
# recycling:glass: object
# recycling:glass_bottles: object
# recycling:green_waste: object
# recycling:paper: object
# recycling:plastic: object
# recycling:scrap_metal: object
# recycling:waste: object
# recycling_type: object
# ref: object
# ref:ckkp: object
# ref:csioz: object
# ref:gez_Kraków: object
# ref:inspire: object
# ref:nid: object
# ref:radiopolska: object
# ref:rspo: object
# ref:vatin: object
# ref_name: object
# religion: object
# religious_title: object
# remotely_controllable: object
# research: object
# reservation: object
# residential: object
# restaurant: object
# roof:colour: object
# roof:construction: object
# roof:direction: object
# roof:height: object
# roof:levels: object
# roof:material: object
# roof:orientation: object
# roof:shape: object
# rooms: object
# ruined: object
# ruins: object
# seasonal: object
# second_hand: object
# self_service: object
# service: object
# service:bicycle:clothing: object
# service:bicycle:pump: object
# service:bicycle:repair: object
# service:bicycle:retail: object
# service:vehicle:air_conditioning: object
# service:vehicle:body_repair: object
# service:vehicle:brakes: object
# service:vehicle:car_parts: object
# service:vehicle:car_repair: object
# service:vehicle:detailing: object
# service:vehicle:diagnostics: object
# service:vehicle:electrical: object
# service:vehicle:inspection: object
# service:vehicle:motor: object
# service:vehicle:muffler: object
# service:vehicle:new_car_sales: object
# service:vehicle:oil_change: object
# service:vehicle:painting: object
# service:vehicle:repairs: object
# service:vehicle:transmission: object
# service:vehicle:transmission_repair: object
# service:vehicle:tyres: object
# service:vehicle:used_car_sales: object
# service:vehicle:wheels: object
# service_times: object
# shed: object
# shelter: object
# shelter_type: object
# shop: object
# short_name: object
# shrine: object
# shrine:name: object
# shrine:object: object
# shrine:type: object
# smoking: object
# social_facility: object
# social_facility:for: object
# source: object
# source:addr: object
# source:addr:housenumber: object
# source:amenity: object
# source:building: object
# source:building:levels: object
# source:female:conditional: object
# source:geometry: object
# source:height: object
# source:name: object
# source:name:en: object
# source:office: object
# source:postcode: object
# spa: object
# sport: object
# stars: object
# start_date: object
# street_cabinet: object
# stroller: object
# studio: object
# subject:wikidata: object
# subject:wikipedia: object
# substation: object
# substation:name: object
# supervised: object
# supporters: object
# surface: object
# surveillance: object
# survey:date: object
# survey_date:shop: object
# swimming_pool:lanes: object
# swimming_pool:length: object
# tactile_paving: object
# takeaway: object
# target: object
# telescope:type: object
# teryt:name: object
# theatre:genre: object
# theatre:type: object
# toilets: object
# toilets:access: object
# toilets:disposal: object
# toilets:fee: object
# toilets:wheelchair: object
# total_height: object
# tourism: object
# tourism:source: object
# tower: object
# tower:construction: object
# tower:type: object
# trade: object
# tram: object
# truck_wash: object
# type: object
# unisex: object
# url: object
# vacuum_cleaner: object
# validate:ants:yellow: object
# voltage: object
# wall: object
# walls: object
# was:name: object
# was:shop: object
# waste: object
# weather_protection: object
# website: object
# website:2: object
# website:menu: object
# website:refugee:uk: object
# wheelchair: object
# wheelchair:description: object
# wikidata: object
# wikimedia_commons: object
# wikimedia_commons:category: object
# wikipedia: object

# %% [markdown]
# Most promising columns are:
# `area`, `type`, `building`, `building:levels`/`building:levels:aboveground`, `building:flats`
#
# and of course we need to keep `id` and `geom`

# %% [markdown]
# ## Explore Data

# %%
print(gdf["area"].describe())
print('-' * 30)
print(gdf["area"].value_counts())
# Out:
# count      13
# unique      1
# top       yes
# freq       13
# Name: area, dtype: object
# ------------------------------
# area
# yes    13
# Name: count, dtype: int64

# %%
print(gdf["type"].describe())
print('-' * 30)
print(gdf["type"].value_counts())
# Out:
# count           26
# unique           2
# top       building
# freq            25
# Name: type, dtype: object
# ------------------------------
# type
# building        25
# indoor_range     1
# Name: count, dtype: int64

# %%
print(gdf["building"].describe())
print("-" * 30)
print(gdf["building"].value_counts())
# Out:
# count     122543
# unique       145
# top          yes
# freq       85888
# Name: building, dtype: object
# ------------------------------
# building
# yes                  85888
# apartments            8405
# house                 4315
# garage                4177
# detached              3991
#                      ...
# nursery                  1
# technical                1
# entrance_building        1
# HVAC                     1
# ger                      1
# Name: count, Length: 145, dtype: int64

# %%
print(gdf["building:levels"].describe())
print("-" * 30)
print(gdf["building:levels"].value_counts())
# Out:
# count     21052
# unique       37
# top           1
# freq       6457
# Name: building:levels, dtype: object
# ------------------------------
# building:levels
# 1      6457
# 2      4598
# 3      3441
# 4      2545
# 5      2031
# 6       544
# 11      311
# 7       248
# 12      190
# 8       157
# 10      113
# 9       103
# 0        95
# 3.5      52
# 4.5      35
# 2.5      29
# 14       22
# 16       16
# 5.5      15
# 1.5      13
# 13        8
# 15        6
# 17        5
# 0.2       3
# 0.8       2
# 0.5       2
# 6.5       1
# 3w        1
# 20        1
# 1.2       1
# -1        1
# 3.8       1
# 27        1
# 1.1       1
# 1.3       1
# 0.3       1
# 1.8       1
# Name: count, dtype: int64

# %%
print(gdf["building:levels:aboveground"].describe())
print("-" * 30)
print(gdf["building:levels:aboveground"].value_counts())
# Out:
# count     5
# unique    2
# top       7
# freq      3
# Name: building:levels:aboveground, dtype: object
# ------------------------------
# building:levels:aboveground
# 7    3
# 5    2
# Name: count, dtype: int64

# %%
print(gdf["building:flats"].describe())
print("-" * 30)
print(gdf["building:flats"].value_counts())
# Out:
# count     60
# unique    31
# top        2
# freq      10
# Name: building:flats, dtype: object
# ------------------------------
# building:flats
# 2      10
# 17      6
# 16      6
# 14      4
# 4       3
# 40      2
# 96      2
# 72      2
# 30      2
# 12      2
# 46      1
# 6       1
# 58      1
# 118     1
# 122     1
# 60      1
# 78      1
# 48      1
# 172     1
# 24      1
# 121     1
# 19      1
# 89      1
# 45      1
# 250     1
# 15      1
# 177     1
# 42      1
# 49      1
# 67      1
# 65      1
# Name: count, dtype: int64

# %% [markdown]
# # Action Plan
#
# Turns out the OSM data is shitty to say the least...
#
# I will use geom column to calculate the areas, and combining this data with building levels (default 3-4) and assuming each level has the same area we can calculate the living_area.
#
# Based on that we will sum all living areas and calculate population density per living area based on krakow's population density.
#
# Next we will take this coefficient and calculate population density on building area per 100m^2

# %% [markdown]
# ### 1. Trim dataset
#
# we only need `id`, `geom`, `building(:type)` and `building:levels`

# %%
gdf = gdf[["id", "geom", "building", "building:levels"]].rename(columns={"building": "building:type"})
gdf.head(2)
# Out:
#           id                                               geom building:type  \
# 0  301173473  POLYGON ((19.89907 49.99811, 19.89908 49.99802...    apartments
# 1  125811727  POLYGON ((19.89869 49.99864, 19.89869 49.99865...           yes
#
#   building:levels
# 0             NaN
# 1               5

# %% [markdown]
# ### 2. Calculate buildings area

# %%
gdf.to_crs(epsg=2180, inplace=True)
gdf["building:area"] = gdf["geom"].area
print(gdf["building:area"].describe())
# Out:
# count    122543.000000
# mean        191.693877
# std         839.324166
# min           0.000239
# 25%          36.228647
# 50%          93.855768
# 75%         155.635441
# max      100527.669597
# Name: building:area, dtype: float64

# %% [markdown]
# ### 3. We need to limit buildings to ony those that are livable
#
# Probably we need to use `building:type` column but most buildings have "yes" and in visualization above we can see that this is the case for also family homes.

# %%
for type in gdf["building:type"].value_counts().index:
    print(type, '\t', gdf["building:type"].value_counts()[type])
# Out:
# yes 	 85888
# apartments 	 8405
# house 	 4315
# garage 	 4177
# detached 	 3991
# residential 	 2073
# service 	 1910
# retail 	 1309
# terrace 	 1057
# garages 	 944
# outbuilding 	 893
# shed 	 725
# roof 	 687
# construction 	 677
# commercial 	 591
# greenhouse 	 510
# industrial 	 494
# office 	 458
# semidetached_house 	 433
# school 	 342
# allotment_house 	 217
# kiosk 	 207
# warehouse 	 203
# university 	 199
# farm_auxiliary 	 192
# church 	 152
# kindergarten 	 130
# hospital 	 109
# hotel 	 92
# grandstand 	 91
# garbage_shed 	 81
# hut 	 58
# carport 	 58
# dormitory 	 56
# chapel 	 53
# civic 	 47
# ruins 	 47
# public 	 37
# convent 	 33
# guardhouse 	 32
# monastery 	 31
# bunker 	 30
# farm 	 27
# bridge 	 25
# presbytery 	 24
# sports_centre 	 22
# bungalow 	 22
# transportation 	 22
# government 	 19
# toilets 	 17
# trash_shed 	 16
# shop 	 16
# barn 	 16
# museum 	 14
# supermarket 	 13
# storage_tank 	 11
# hangar 	 10
# synagogue 	 10
# train_station 	 9
# parking 	 9
# religious 	 8
# cloister 	 7
# library 	 7
# proposed 	 7
# waste_shed 	 6
# chimney 	 6
# transformer_tower 	 6
# college 	 6
# houseboat 	 6
# palace 	 5
# sports_hall 	 5
# tower 	 4
# stadium 	 4
# tent 	 4
# pavilion 	 4
# boat 	 4
# container 	 4
# shrine 	 4
# stable 	 4
# planned 	 4
# passage 	 4
# depot 	 3
# car_wash 	 3
# water_tower 	 3
# vestibule 	 3
# fire_station 	 3
# theatre 	 3
# bus_station 	 3
# no 	 3
# sty 	 2
# waste_disposal 	 2
# resort 	 2
# air_shaft 	 2
# cowshed 	 2
# roundhouse 	 2
# fortification 	 2
# historic 	 2
# restaurant 	 2
# guard_cabin 	 2
# walkway 	 2
# wall 	 2
# fort 	 2
# gymnasium 	 2
# hall 	 2
# connector 	 2
# bell_tower 	 2
# garbage_shedq 	 2
# substation 	 1
# swimming_pool 	 1
# storage 	 1
# railway 	 1
# waste_disposal_shed 	 1
# elevator_housing 	 1
# collapsed 	 1
# social_facility 	 1
# tank 	 1
# cinema 	 1
# fuel_station 	 1
# manufacture 	 1
# prison 	 1
# weir 	 1
# bank 	 1
# budynek_małopolskiego_urzędu_marszałkowskiego 	 1
# police 	 1
# cle 	 1
# rzeź 	 1
# shooting range 	 1
# forge 	 1
# yes;apartments 	 1
# static_caravan 	 1
# guard_housing 	 1
# cathedral 	 1
# wayside_shrine 	 1
# crossing_keeper_cabin 	 1
# stairs 	 1
# exhibition 	 1
# parking_entrance 	 1
# workshop 	 1
# philharmonic 	 1
# doctors 	 1
# nursery 	 1
# technical 	 1
# entrance_building 	 1
# HVAC 	 1
# ger 	 1

# %% [markdown]
# #### 3.1. Definitely livable buildings

# %%
definitely_livable_types = [
    "apartments",
    "house",
    "detached",
    "semidetached_house",
    "residential",
    "dormitory",
]

definitely_livable = gdf[gdf["building:type"].isin(definitely_livable_types)].copy()
print(definitely_livable["building:area"].describe())
# Out:
# count    19273.000000
# mean       310.990915
# std        359.449087
# min          5.506919
# 25%        108.148276
# 50%        160.780730
# 75%        370.081804
# max       7177.797287
# Name: building:area, dtype: float64

# %%
print(definitely_livable["building:levels"].describe())
print("-" * 30)
print(definitely_livable["building:levels"].value_counts())
print("-" * 30)
print(definitely_livable["building:levels"].isnull().sum())
# Out:
# count     10834
# unique       23
# top           2
# freq       2434
# Name: building:levels, dtype: object
# ------------------------------
# building:levels
# 2      2434
# 3      1980
# 4      1673
# 1      1620
# 5      1610
# 6       416
# 11      292
# 7       187
# 12      172
# 8       134
# 10       85
# 9        84
# 0        36
# 3.5      24
# 4.5      22
# 16       16
# 14       15
# 5.5       9
# 2.5       8
# 13        7
# 15        6
# 17        3
# 1.5       1
# Name: count, dtype: int64
# ------------------------------
# 8439

# %%
definitely_livable.fillna({"building:levels": 2}, inplace=True)

# %%
definitely_livable.head()
# Out:
#           id                                               geom building:type  \
# 0  301173473  POLYGON ((564416.744 237145.386, 564417.105 23...    apartments
# 2  301173396  POLYGON ((564403.357 237147.948, 564403.349 23...    apartments
# 3  692996137  POLYGON ((564386.02 236941.818, 564398.505 236...    apartments
# 4  769991350  POLYGON ((564688.179 236921.29, 564687.175 236...    apartments
# 5  965591141  POLYGON ((564766.96 236962.361, 564769.784 236...    apartments
#
#   building:levels  building:area
# 0               2     134.073271
# 2               2     164.338593
# 3               2    1126.355321
# 4               2     972.286428
# 5               2    1108.686775

# %% [markdown]
# #### 3.2. Potentially livable buildings

# %%
type_yes = gdf[gdf["building:type"] == "yes"].copy()
print(type_yes["building:area"].describe())
# Out:
# count     85888.000000
# mean        139.515000
# std         527.725429
# min           0.000239
# 25%          32.328275
# 50%          85.299460
# 75%         133.871657
# max      100527.669597
# Name: building:area, dtype: float64

# %%
livable_yes = type_yes[70 <= type_yes["building:area"]]
livable_yes = livable_yes[livable_yes["building:area"] <= 800]
print(livable_yes["building:area"].describe())
# Out:
# count    47715.000000
# mean       161.083570
# std        115.524326
# min         70.002324
# 25%         96.727293
# 50%        122.098278
# 75%        170.035039
# max        799.578648
# Name: building:area, dtype: float64

# %%
print(livable_yes["building:levels"].describe())
print("-" * 30)
print(livable_yes["building:levels"].value_counts())
print("-" * 30)
print(livable_yes["building:levels"].isnull().sum())
# Out:
# count     3858
# unique      22
# top          2
# freq      1045
# Name: building:levels, dtype: object
# ------------------------------
# building:levels
# 2      1045
# 3       904
# 1       874
# 4       580
# 5       262
# 6        63
# 3.5      27
# 2.5      16
# 0        15
# 4.5      12
# 7        12
# 12        9
# 11        9
# 8         7
# 10        7
# 1.5       6
# 5.5       4
# 14        2
# 3.8       1
# 6.5       1
# 9         1
# 1.8       1
# Name: count, dtype: int64
# ------------------------------
# 43857

# %%
livable_yes.fillna({"building:levels": 2}, inplace=True)

# %% [markdown]
# #### 3.3. All buildings assumed as livable

# %%
livable_buildings = pd.concat([livable_yes, definitely_livable])

# %% [markdown]
# ### 4. calculate living area

# %%
livable_buildings["building:levels"] = livable_buildings["building:levels"].astype(float)

# %%
livable_buildings["building:floor_space"] =\
    livable_buildings["building:area"] * livable_buildings["building:levels"]

# %%
print(livable_buildings.dtypes)

livable_buildings.describe()
# Out:
# id                         int64
# geom                    geometry
# building:type             object
# building:levels          float64
# building:area            float64
# building:floor_space     float64
# dtype: object
#                  id  building:levels  building:area  building:floor_space
# count  6.698800e+04     66988.000000   66988.000000          66988.000000
# mean   3.592588e+08         2.311498     204.213149            605.217059
# std    2.785635e+08         1.244984     226.457557           1346.301294
# min    2.524742e+07         0.000000       5.506919              0.000000
# 25%    1.625988e+08         2.000000      98.697915            193.942376
# 50%    2.333724e+08         2.000000     129.124953            256.981705
# 75%    3.395740e+08         2.000000     199.132022            416.655447
# max    1.326332e+09        17.000000    7177.797287          57422.378296

# %% [markdown]
# ### 5. Calculating density

# %%
KRAKOW_POPULATION = 790_000

all_floor_space = livable_buildings["building:floor_space"].sum()
print(f"{all_floor_space=:.3f}")

density_coefficient = KRAKOW_POPULATION / all_floor_space
print(f"{density_coefficient=:.3f}")

density_per_100m2 = density_coefficient * 100
print(f"{density_per_100m2=:.3f}") # 1.95 people per 100m2 - seems reasonable
# Out:
# all_floor_space=40542280.346
# density_coefficient=0.019
# density_per_100m2=1.949

# %%
livable_buildings["building:population"] = livable_buildings["building:floor_space"] * density_coefficient
livable_buildings["building:density_per_100m2"] = livable_buildings["building:population"] / livable_buildings["building:area"] * 100

# %%
livable_buildings.head()
# Out:
#             id                                               geom  \
# 18   161678891  POLYGON ((564801.322 237252.039, 564796.226 23...
# 19   161678957  POLYGON ((564794.672 237277.515, 564794.533 23...
# 24   337197358  POLYGON ((564923.468 236804.199, 564926.911 23...
# 74  1219360898  POLYGON ((564936.177 235994.116, 564934.704 23...
# 75  1219360895  POLYGON ((564930.424 236021.749, 564928.965 23...
#
#    building:type  building:levels  building:area  building:floor_space  \
# 18           yes              2.0     180.417926            360.835852
# 19           yes              2.0     254.323445            508.646891
# 24           yes              2.0     116.156960            232.313920
# 74           yes              2.0      74.174188            148.348376
# 75           yes              2.0      74.558950            149.117900
#
#     building:population  building:density_per_100m2
# 18             7.031186                    3.897166
# 19             9.911407                    3.897166
# 24             4.526830                    3.897166
# 74             2.890691                    3.897166
# 75             2.905686                    3.897166

# %% [markdown]
# ### 6. Save results

# %%
livable_buildings.to_pickle("livable_buildings_with_density.pkl")
